# %% [markdown]
# # This Page is a Template
#
# The top-level header (the one above, using one \# in markdown) becomes the name of the page in the table of contents.
#
# Below, we can show an example plot.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,10,100)
plt.plot(x, np.sin(x))
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.title('A Simple Plot')
plt.show()
